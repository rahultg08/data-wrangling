# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding="latin1")

# %%
df.sample(5)
# Out:
#        Area Code                         Area  Item Code  \
# 1257           4                      Algeria       2961
# 51256        276                        Sudan       2511
# 57338        215  United Republic of Tanzania       2579
# 57071        215  United Republic of Tanzania       2912
# 20583         74                        Gabon       2516
#
#                           Item  Element Code  \
# 1257   Aquatic Products, Other          5911
# 51256       Wheat and products          5170
# 57338           Sesameseed Oil           674
# 57071                 Treenuts          5123
# 20583                     Oats          5911
#
#                                       Element          Unit  Y2014  Y2015  \
# 1257                          Export Quantity   1000 tonnes    0.0    0.0
# 51256                               Residuals   1000 tonnes    0.0    0.0
# 57338  Protein supply quantity (g/capita/day)  g/capita/day    0.0    0.0
# ...

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.tail()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 60938                                    Food      1000 tonnes  42.00  46.00
# 60939     Food supply quantity (kg/capita/yr)               kg   3.06   3.33
# 60940           Food supply (kcal/capita/day)  kcal/capita/day   3.00   4.00
# 60941  Protein supply quantity (g/capita/day)     g/capita/day   0.10   0.11
# 60942      Fat supply quantity (g/capita/day)     g/capita/day   0.04   0.05
#
#        Y2016  Y2017  Y2018
# 60938  33.00  19.00  16.00
# 60939   2.35   1.33   1.08
# ...

# %%
my_tuppy = (1,2,5,8)

# %%
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e0cfa6830280> in <module>
# ----> 1 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

# %%
y[1][1]
# Out:
# 8

# %%
y[1][-1]
# Out:
# 8

# %%
df.groupby('Area')['Area'].count()
# Out:
# Area
# Algeria                        1313
# Angola                         1424
# Benin                          1285
# Botswana                       1378
# Burkina Faso                   1409
# Cabo Verde                     1260
# Cameroon                       1460
# Central African Republic       1344
# Chad                           1343
# Comoros                          45
# Congo                          1413
# Côte d'Ivoire                  1467
# Djibouti                       1095
# Egypt                          1488
# Eswatini                       1284
# Ethiopia                       1447
# Ethiopia PDR                     39
# Gabon                          1245
# Gambia                         1168
# Ghana                          1354
# Guinea                         1410
# Guinea-Bissau                  1128
# Kenya                          1560
# Lesotho                        1150
# Liberia                        1206
# Madagascar                     1439
# ...

# %%
df.groupby('Area')['Area'].count().count()
# Out:
# 49

# %%
df.groupby('Area')['Y2017']

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df['Y2017']
# Out:
# 0        41389.00
# 1            0.00
# 2         3341.00
# 3           92.82
# 4           80.19
#            ...
# 60938       19.00
# 60939        1.33
# 60940        1.00
# 60941        0.04
# 60942        0.02
# Name: Y2017, Length: 60943, dtype: float64

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.loc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df[df['Area'] == 'Madagascar']
# Out:
#        Area Code        Area  Item Code           Item  Element Code  \
# 30715        129  Madagascar       2501     Population           511
# 30716        129  Madagascar       2501     Population          5301
# 30717        129  Madagascar       2901    Grand Total           664
# 30718        129  Madagascar       2901    Grand Total           674
# 30719        129  Madagascar       2901    Grand Total           684
# ...          ...         ...        ...            ...           ...
# 32149        129  Madagascar       2899  Miscellaneous          5142
# 32150        129  Madagascar       2899  Miscellaneous           645
# 32151        129  Madagascar       2899  Miscellaneous           664
# 32152        129  Madagascar       2899  Miscellaneous           674
# 32153        129  Madagascar       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# ...

# %%
df[df['Area']=='Madagascar'].groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                    15351     318888        630819
# Export Quantity                             13416     279445        614744
# Fat supply quantity (g/capita/day)          14319     299405         75924
# Feed                                         4515      94030        193235
# Food                                        14190     295817        565620
# Food supply (kcal/capita/day)               14319     299405         73704
# Food supply quantity (kg/capita/yr)         14190     295817         70950
# Import Quantity                             14319     297945        622821
# Losses                                       7095     148102        281765
# Other uses (non-food)                        6579     138246        262854
# Processing                                   9804     201929        389956
# ...

# %%
df[df['Area']=='Madagascar'].groupby('Element').sum()['Y2015']
# Out:
# Element
# Domestic supply quantity                  31214.98
# Export Quantity                             494.75
# Fat supply quantity (g/capita/day)           91.85
# Feed                                       2070.22
# Food                                      21120.65
# Food supply (kcal/capita/day)              7685.00
# Food supply quantity (kg/capita/yr)         871.59
# Import Quantity                            1721.80
# Losses                                     2176.00
# Other uses (non-food)                      3957.12
# Processing                                 1803.00
# Production                                29482.89
# Protein supply quantity (g/capita/day)      173.05
# Residuals                                  -616.00
# Seed                                        699.00
# Stock Variation                            -505.00
# Total Population - Both sexes             24234.00
# Name: Y2015, dtype: float64

# %%
df[df['Area']=='Madagascar'].groupby('Element').sum()['Y2015'].loc['Protein supply quantity (g/capita/day)']
# Out:
# 173.04999999999998

# %%
df.groupby("Element")["Y2014"].sum()
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
df1 = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding="latin1")

# %%
df1.groupby("Element")["Y2014"].sum()["Stock Variation"]
# Out:
# 58749.82999999999

# %%
df1.groupby("Element")["Y2015"].sum()["Stock Variation"]
# Out:
# 34910.99

# %%
df1.groupby("Element")["Y2016"].sum()["Stock Variation"]
# Out:
# 33140.12000000001

# %%
df1.groupby("Element")["Y2017"].sum()["Stock Variation"]
# Out:
# 54316.909999999996

# %%
df1.groupby("Element")["Y2018"].sum()["Stock Variation"]
# Out:
# 20577.910000000003

# %%
df1.groupby("Element").sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
df1.groupby("Element").sum().loc['Stock Variation']
# Out:
# Area Code         571566.00
# Item Code       11329527.00
# Element Code    21464704.00
# Y2014              58749.83
# Y2015              34910.99
# Y2016              33140.12
# Y2017              54316.91
# Y2018              20577.91
# Name: Stock Variation, dtype: float64

# %%
df1.groupby('Element Code').corr()
# Out:
#                         Area Code  Item Code     Y2014     Y2015     Y2016  \
# Element Code
# 511          Area Code   1.000000        NaN  0.149348  0.149792  0.150292
#              Item Code        NaN        NaN       NaN       NaN       NaN
#              Y2014       0.149348        NaN  1.000000  0.999988  0.999951
#              Y2015       0.149792        NaN  0.999988  1.000000  0.999987
#              Y2016       0.150292        NaN  0.999951  0.999987  1.000000
# ...                           ...        ...       ...       ...       ...
# 5911         Y2014       0.005901   0.056301  1.000000  0.976942  0.992694
#              Y2015       0.007883   0.050526  0.976942  1.000000  0.965195
#              Y2016       0.006203   0.062306  0.992694  0.965195  1.000000
#              Y2017       0.005156   0.063080  0.941934  0.863665  0.963790
#              Y2018       0.004272   0.063211  0.942024  0.863140  0.963378
#
#                            Y2017     Y2018
# ...

# %%
df1.groupby('Element Code').corr().sum()
# Out:
# Area Code    18.493731
# Item Code    25.835666
# Y2014        86.012975
# Y2015        85.248146
# Y2016        87.093281
# Y2017        86.958780
# Y2018        86.516790
# dtype: float64

# %%
df.shape
# Out:
# (60943, 12)

# %%
len(df)
# Out:
# 60943

# %%
n_rows = len(df.axes[0])

# %%
n_rows
# Out:
# 60943

# %%
n_col = len(df.axes[1])

# %%
n_col
# Out:
# 12

# %%
n_rows1 = len(df)

# %%
n_rows1
# Out:
# 60943

# %%
n_col = len(df.columns)

# %%
n_col
# Out:
# 12

# %%
S = [['him', 'sell'], [90, 28, 43]]

# %%
S[0][1][1]
# Out:
# 'e'

# %%
df1['Y2014'].isnull().sum()
# Out:
# 1589

# %%
df1['Y2014'].count()
# Out:
# 59354

# %%
(1589/59354)*100
# Out:
# 2.6771573946153584

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

# %%
col = ['Age', 'Nationality', 'Overall']

# %%
pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
pd.DataFrame(lst, columns = ['Age', 'Nationality', 'Overall'], index = [1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
pd.DataFrame(lst, columns = col, index = [1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
df1.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
df1.groupby('Item').sum().loc['Wine']
# Out:
# Area Code         66206.00
# Item Code       1319535.00
# Element Code    1818328.00
# Y2014              4497.36
# Y2015              4251.81
# Y2016              3872.09
# Y2017              4178.02
# Y2018              4039.32
# Name: Wine, dtype: float64

# %%
df1.groupby('Item').sum().loc['Wine'].loc['Y2015']
# Out:
# 4251.8099999999995

# %%
df1.groupby('Item').sum().loc['Wine'].loc['Y2018']
# Out:
# 4039.3199999999997

# %%
df1.groupby('Area').loc['Y2015']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-134-f97c0ad06fdf> in <module>
# ----> 1 df1.groupby('Area').loc['Y2015']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'loc'

# %%
df1['Y2017'].mean()
# Out:
# 140.917764860268

# %%
df1['Y2017'].std()
# Out:
# 1671.8623590572788

# %%
df1.groupby('Area').sum()
# Out:
#                              Area Code  Item Code  Element Code       Y2014  \
# Area
# Algeria                           5252    3532053       5017927   313375.33
# Angola                            9968    3819908       5515088   208584.42
# Benin                            68105    3453692       4852820   118050.79
# Botswana                         27560    3704902       5259784    22339.92
# Burkina Faso                    328297    3778795       5431243   105051.33
# Cabo Verde                       44100    3396746       4787751    14576.94
# Cameroon                         46720    3916078       5663196   217630.28
# Central African Republic         49728    3607546       5069094    28739.02
# Chad                             52377    3606529       5108355    65940.17
# Comoros                           2025     124514        241681       32.00
# Congo                            64998    3792029       5445560    38699.26
# ...

# %%
df1.groupby('Area').sum()['Y2017']
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
df1.groupby('Area').sum()['Y2017'].max()
# Out:
# 1483268.2300000011

# %%
df1.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
df1.groupby('Element').sum()['Y2017']
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
df1.groupby('Element').sum()['Y2017'].loc['Processing']
# Out:
# 292836.0

# %%
df1.groupby('Area').sum()
# Out:
#                              Area Code  Item Code  Element Code       Y2014  \
# Area
# Algeria                           5252    3532053       5017927   313375.33
# Angola                            9968    3819908       5515088   208584.42
# Benin                            68105    3453692       4852820   118050.79
# Botswana                         27560    3704902       5259784    22339.92
# Burkina Faso                    328297    3778795       5431243   105051.33
# Cabo Verde                       44100    3396746       4787751    14576.94
# Cameroon                         46720    3916078       5663196   217630.28
# Central African Republic         49728    3607546       5069094    28739.02
# Chad                             52377    3606529       5108355    65940.17
# Comoros                           2025     124514        241681       32.00
# Congo                            64998    3792029       5445560    38699.26
# ...

# %%
df1.groupby('Area').sum()['Y2017'].sort_values()
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
df1.groupby('Area').sum()['Y2017'].sort_values().iloc[6]
# Out:
# 19102.77
